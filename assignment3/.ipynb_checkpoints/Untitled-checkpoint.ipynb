# %%
import pandas as pd
import matplotlib.pyplot as plt
import pylab
import matplotlib
import numpy as np

# %%
history = pd.read_csv('web_count.csv')
history = history.sort_values(by='count', ascending=False)
history_filtered = history[9:29]
history_filtered
# Out:
#                               count
# www.sports-reference.com        133
# stackoverflow.com                90
# gmail.com                        82
# groups.google.com                81
# drive.google.com                 77
# 10.10.0.1                        54
# portal2.passportindia.gov.in     53
# manipal.examcloud.in             50
# www.tutorialspoint.com           49
# www.abhibus.com                  48
# askubuntu.com                    40
# docs.mongodb.com                 39
# www.pythonforbeginners.com       31
# www.cloudera.com                 26
# plot.ly                          23
# accounts.youtube.com             22
# lms.simplilearn.com              20
# www.ksrtc.in                     19
# en.wikipedia.org                 18
# www.uship.com                    18

# %%
history_filtered.plot(kind='barh', title='Deaths for under 5yrs of age for developed region in 2000 and 2015', rot=1, color=(['m']),
                  figsize=(11, 9), edgecolor='w', linewidth=2, width=0.7)
plt.xlabel('<------ Total count ------>', fontsize=14, color='m')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
